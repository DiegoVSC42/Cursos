# %%
import pandas as pd

# %%
import json

with open('cursos_cadastrados.json', 'r') as f:
    json_bruto = json.load(f)

dados = pd.json_normalize(json_bruto)

# %%
dados
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1             Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 3          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
# 4            InglÃªs para negÃ³cios        Idiomas      20 horas          30
# 5     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90     JoÃ£o Silva
# 1                                               None   None  Maria Oliveira
# ...

# %% [markdown]
# Removendo Duplicatas

# %%
dados.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
filtro_duplicadas = dados.duplicated()

# %%
dados[filtro_duplicadas]
# Out:
#                            curso      categoria carga_horaria concluintes  \
# 5  IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao                                        descricao  \
# 5  2022-01-01     2022-01-20  Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# 5  99.90    JoÃ£o Silva  joao.silva@emailaleatorio.com     (11) 9999-9999

# %%
dados_sem_duplicadas = dados.drop_duplicates()

# %%
dados_sem_duplicadas
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1             Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 3          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
# 4            InglÃªs para negÃ³cios        Idiomas      20 horas          30
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
#
#                                            descricao  preco  instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90     JoÃ£o Silva
# 1                                               None   None  Maria Oliveira
# 2                   Curso introdutÃ³rio em marketing   89.9      Ana Santos
# 3  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9
# ...

# %% [markdown]
# Verificando Nulos

# %%
dados.isna()
# Out:
#    curso  categoria  carga_horaria  concluintes  data_inicio  data_conclusao  \
# 0  False      False          False        False        False           False
# 1  False      False           True         True         True            True
# 2  False      False          False        False        False           False
# 3  False      False          False        False        False           False
# 4  False      False          False        False        False           False
# 5  False      False          False        False        False           False
#
#    descricao  preco  instrutor.nome  instrutor.email  instrutor.telefone
# 0      False  False           False            False               False
# 1       True   True           False            False               False
# 2      False  False           False            False               False
# 3      False  False           False            False               False
# ...

# %%
dados.isna().sum()
# Out:
# curso                 0
# categoria             0
# carga_horaria         1
# concluintes           1
# data_inicio           1
# data_conclusao        1
# descricao             1
# preco                 1
# instrutor.nome        0
# instrutor.email       0
# instrutor.telefone    0
# dtype: int64

# %%
dados.isna().sum().sum()
# Out:
# np.int64(6)

# %%
filtro = dados["data_inicio"].isna()
filtro
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: data_inicio, dtype: bool

# %%
dados_sem_nulos = dados.dropna()

# %%
dados_sem_nulos
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 2  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 3          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
# 4            InglÃªs para negÃ³cios        Idiomas      20 horas          30
# 5     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90    JoÃ£o Silva
# 2                   Curso introdutÃ³rio em marketing   89.9     Ana Santos
# 3  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9
# 4                    Curso de inglÃªs para negÃ³cios   69.9     John Smith
# ...

# %%
dados_sem_nulos = dados_sem_nulos.reset_index(drop=True)

# %%
dados_sem_nulos
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 2          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
# 3            InglÃªs para negÃ³cios        Idiomas      20 horas          30
# 4     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1  2022-03-01     2022-03-31
# 2  2022-04-01
# 3
# 4  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90    JoÃ£o Silva
# 1                   Curso introdutÃ³rio em marketing   89.9     Ana Santos
# 2  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9
# 3                    Curso de inglÃªs para negÃ³cios   69.9     John Smith
# ...

# %%
dados[dados["instrutor.nome"] ==""]
# Out:
#                       curso      categoria carga_horaria concluintes  \
# 3  InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
#
#   data_inicio data_conclusao  \
# 3  2022-04-01
#
#                                            descricao  preco instrutor.nome  \
# 3  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9
#
#               instrutor.email instrutor.telefone
# 3  contato@emailaleatorio.com

# %%
dados[dados["data_conclusao"] == ""]
# Out:
#                       curso      categoria carga_horaria concluintes  \
# 3  InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
# 4    InglÃªs para negÃ³cios        Idiomas      20 horas          30
#
#   data_inicio data_conclusao  \
# 3  2022-04-01
# 4
#
#                                            descricao  preco instrutor.nome  \
# 3  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9
# 4                    Curso de inglÃªs para negÃ³cios   69.9     John Smith
#
#               instrutor.email instrutor.telefone
# 3  contato@emailaleatorio.com
# 4

# %%
dados_sem_strings_vazias = dados.replace("",pd.NA)

# %%
dados_sem_strings_vazias
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1             Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 3          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas        <NA>
# 4            InglÃªs para negÃ³cios        Idiomas      20 horas          30
# 5     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01           <NA>
# 4        <NA>           <NA>
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90     JoÃ£o Silva
# ...

# %%
dados_sem_strings_vazias_e_nulos = dados.dropna()

# %%
dados_sem_strings_vazias_e_nulos
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 2  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 3          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
# 4            InglÃªs para negÃ³cios        Idiomas      20 horas          30
# 5     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90    JoÃ£o Silva
# 2                   Curso introdutÃ³rio em marketing   89.9     Ana Santos
# 3  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9
# 4                    Curso de inglÃªs para negÃ³cios   69.9     John Smith
# ...

# %%
df = dados

# %%
df = dados

# %%
df = df.drop_duplicates()
df
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1             Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 3          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas
# 4            InglÃªs para negÃ³cios        Idiomas      20 horas          30
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
#
#                                            descricao  preco  instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90     JoÃ£o Silva
# 1                                               None   None  Maria Oliveira
# 2                   Curso introdutÃ³rio em marketing   89.9      Ana Santos
# 3  Curso avanÃ§ado sobre inteligÃªncia artificial...  129.9
# ...

# %%
df = df.replace("",pd.NA)
df
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 1             Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negÃ³cios      Marketing      30 horas          75
# 3          InteligÃªncia artificial  ProgramaÃ§Ã£o      40 horas        <NA>
# 4            InglÃªs para negÃ³cios        Idiomas      20 horas          30
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01           <NA>
# 4        <NA>           <NA>
#
#                                            descricao  preco  instrutor.nome  \
# 0    Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python  99.90     JoÃ£o Silva
# 1                                               None   None  Maria Oliveira
# 2                   Curso introdutÃ³rio em marketing   89.9      Ana Santos
# ...

# %%
df = df.dropna()
df
# Out:
#                               curso      categoria carga_horaria concluintes  \
# 0     IntroduÃ§Ã£o Ã  programaÃ§Ã£o  ProgramaÃ§Ã£o      20 horas         100
# 2  Marketing digital para negÃ³cios      Marketing      30 horas          75
#
#   data_inicio data_conclusao                                        descricao  \
# 0  2022-01-01     2022-01-20  Curso introdutÃ³rio Ã  programaÃ§Ã£o com Python
# 2  2022-03-01     2022-03-31                 Curso introdutÃ³rio em marketing
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# 0  99.90    JoÃ£o Silva  joao.silva@emailaleatorio.com     (11) 9999-9999
# 2   89.9     Ana Santos  ana.santos@emailaleatorio.com     (11) 7777-7777

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 2
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               2 non-null      object
#  1   categoria           2 non-null      object
#  2   carga_horaria       2 non-null      object
#  3   concluintes         2 non-null      object
#  4   data_inicio         2 non-null      object
#  5   data_conclusao      2 non-null      object
#  6   descricao           2 non-null      object
#  7   preco               2 non-null      object
#  8   instrutor.nome      2 non-null      object
#  9   instrutor.email     2 non-null      object
#  10  instrutor.telefone  2 non-null      object
# dtypes: object(11)
# memory usage: 192.0+ bytes

# %%
df['concluintes'] = df['concluintes'].astype(int)
df['data_inicio'] = pd.to_datetime(df['data_inicio'])
df['data_conclusao'] = pd.to_datetime(df['data_conclusao'])
df['preco'] = df['preco'].astype(float)
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_12388\3578359321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['concluintes'] = df['concluintes'].astype(int)
# C:\Users\Diego\AppData\Local\Temp\ipykernel_12388\3578359321.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['data_inicio'] = pd.to_datetime(df['data_inicio'])
# C:\Users\Diego\AppData\Local\Temp\ipykernel_12388\3578359321.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 2
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               2 non-null      object
#  1   categoria           2 non-null      object
#  2   carga_horaria       2 non-null      object
#  3   concluintes         2 non-null      int64
#  4   data_inicio         2 non-null      datetime64[ns]
#  5   data_conclusao      2 non-null      datetime64[ns]
#  6   descricao           2 non-null      object
#  7   preco               2 non-null      float64
#  8   instrutor.nome      2 non-null      object
#  9   instrutor.email     2 non-null      object
#  10  instrutor.telefone  2 non-null      object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(7)
# memory usage: 192.0+ bytes
