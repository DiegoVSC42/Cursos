# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Diego\OneDrive\Documentos\GIT\Cursos\Alura\Avançando em Data Science com Python\01 - Visualização de dados\01 - criando gráficos com bibliotecas Python\imigrantes_canada.csv")

# %%
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df.set_index("País",inplace = True)

# %%
df
# Out:
#                 Continente            Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia       Sul da Ásia    16    39    39    47    71
# Albânia             Europa     Sul da Europa     1     0     0     0     0
# Argélia             África   Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia         Polinésia     0     1     0     0     0
# Andorra             Europa     Sul da Europa     0     0     0     0     0
# ...                    ...               ...   ...   ...   ...   ...   ...
# Vietnã                Ásia  Sudeste Asiático  1191  1829  2162  3404  7583
# Saara Ocidental     África   Norte da África     0     0     0     0     0
# Iémen                 Ásia    Ásia Ocidental     1     2     1     6     0
# Zâmbia              África   África Oriental    11    17    11     7    16
# Zimbábue            África   África Oriental    72   114   102    44    32
#
# ...

# %%
anos = list(map(str,range(1980,2014)))

# %%
brasil = df.loc["Brasil",anos]
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
argentina = df.loc["Argentina",anos]
argentina
# Out:
# 1980     368
# 1981     426
# 1982     626
# 1983     241
# 1984     237
# 1985     196
# 1986     213
# 1987     519
# 1988     374
# 1989     538
# 1990     678
# 1991     763
# 1992    1023
# 1993    1022
# 1994     366
# 1995     380
# 1996     396
# 1997     391
# 1998     349
# 1999     318
# 2000     427
# 2001     635
# 2002     865
# 2003    1745
# 2004    1591
# 2005    1153
# 2006     847
# 2007     620
# 2008     540
# 2009     467
# 2010     459
# 2011     278
# 2012     263
# 2013     282
# Name: Argentina, dtype: object

# %%
brasil_dict = {"ano" : brasil.index.tolist(),"imigrantes": brasil.values.tolist()}
dados_brasil = pd.DataFrame(brasil_dict)
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
argentina_dict = {"ano" : argentina.index.tolist(), "imigrantes": argentina.values.tolist()}
dados_argentina = pd.DataFrame(argentina_dict)
dados_argentina
# Out:
#      ano  imigrantes
# 0   1980         368
# 1   1981         426
# 2   1982         626
# 3   1983         241
# 4   1984         237
# 5   1985         196
# 6   1986         213
# 7   1987         519
# 8   1988         374
# 9   1989         538
# 10  1990         678
# 11  1991         763
# 12  1992        1023
# 13  1993        1022
# 14  1994         366
# 15  1995         380
# 16  1996         396
# 17  1997         391
# 18  1998         349
# 19  1999         318
# 20  2000         427
# 21  2001         635
# 22  2002         865
# 23  2003        1745
# 24  2004        1591
# 25  2005        1153
# 26  2006         847
# 27  2007         620
# 28  2008         540
# 29  2009         467
# 30  2010         459
# 31  2011         278
# 32  2012         263
# 33  2013         282

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dados_brasil["ano"],dados_brasil["imigrantes"])

# %%
plt.plot(dados_brasil["ano"],dados_brasil["imigrantes"])
plt.xticks(["1980","1985","1990","1995","2000","2005","2010"])
# Out:
# ([<matplotlib.axis.XTick at 0x29401a64e90>,
# ...
#  [Text(0.0, 0, '1980'),
#   Text(5.0, 0, '1985'),
#   Text(10.0, 0, '1990'),
#   Text(15.0, 0, '1995'),
#   Text(20.0, 0, '2000'),
#   Text(25.0, 0, '2005'),
#   Text(30.0, 0, '2010')])

# %%
plt.plot(dados_brasil["ano"],dados_brasil["imigrantes"])
plt.xticks(["1980","1985","1990","1995","2000","2005","2010"])
plt.yticks([500,1000,1500,2000, 2500, 3000])
# Out:
# ([<matplotlib.axis.YTick at 0x29403b220c0>,
# ...
#  [Text(0, 500, '500'),
#   Text(0, 1000, '1000'),
#   Text(0, 1500, '1500'),
#   Text(0, 2000, '2000'),
#   Text(0, 2500, '2500'),
#   Text(0, 3000, '3000')])

# %%
plt.plot(dados_argentina["ano"],dados_argentina["imigrantes"])
plt.xticks(["1980","1985","1990","1995","2000","2005","2010"])
plt.yticks([500,1000,1500,2000, 2500, 3000])
# Out:
# ([<matplotlib.axis.YTick at 0x29403b929c0>,
# ...
#  [Text(0, 500, '500'),
#   Text(0, 1000, '1000'),
#   Text(0, 1500, '1500'),
#   Text(0, 2000, '2000'),
#   Text(0, 2500, '2500'),
#   Text(0, 3000, '3000')])

# %%
plt.plot(dados_argentina["ano"],dados_brasil["imigrantes"],dados_argentina["imigrantes"])

# %%
plt.plot(dados_argentina["ano"],dados_brasil["imigrantes"],dados_argentina["imigrantes"])
plt.xticks(["1980","1985","1990","1995","2000","2005","2010"])
plt.yticks([500,1000,1500,2000, 2500, 3000])
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(dados_argentina["ano"],dados_brasil["imigrantes"],dados_argentina["imigrantes"])
plt.title("Imigração do Brasil e da Argentina para o Canadá")
plt.xlabel("Ano")
plt.ylabel("Número de Imigrantes")
plt.xticks(["1980","1985","1990","1995","2000","2005","2010"])
plt.yticks([500,1000,1500,2000, 2500, 3000])
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(dados_argentina["ano"],dados_brasil["imigrantes"],dados_argentina["imigrantes"])
plt.title("Imigração do Brasil e da Argentina para o Canadá")
plt.xlabel("Ano")
plt.ylabel("Número de Imigrantes")
plt.xticks(["1980","1985","1990","1995","2000","2005","2010"])
plt.yticks([500,1000,1500,2000, 2500, 3000])
plt.legend()
plt.show()
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_9704\958760907.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(8,4))
plt.plot(dados_brasil["imigrantes"],label = "Brasil")
plt.plot(dados_argentina["imigrantes"],label = "Argentina")
plt.title("Imigração do Brasil e da Argentina para o Canadá")
plt.xlabel("Ano")
plt.ylabel("Número de Imigrantes")
plt.xticks(["1980","1985","1990","1995","2000","2005","2010"])
plt.yticks([500,1000,1500,2000, 2500, 3000])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\matplotlib\axis.py:1804, in Axis.convert_units(self, x)
#    1803 try:
# -> 1804     ret = self.converter.convert(x, self.units, self)
#    1805 except Exception as e:
#
# File c:\Python312\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
# ...

# %%
df
# Out:
#                 Continente            Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia       Sul da Ásia    16    39    39    47    71
# Albânia             Europa     Sul da Europa     1     0     0     0     0
# Argélia             África   Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia         Polinésia     0     1     0     0     0
# Andorra             Europa     Sul da Europa     0     0     0     0     0
# ...                    ...               ...   ...   ...   ...   ...   ...
# Vietnã                Ásia  Sudeste Asiático  1191  1829  2162  3404  7583
# Saara Ocidental     África   Norte da África     0     0     0     0     0
# Iémen                 Ásia    Ásia Ocidental     1     2     1     6     0
# Zâmbia              África   África Oriental    11    17    11     7    16
# Zimbábue            África   África Oriental    72   114   102    44    32
#
# ...

# %%
df_comparacao = df.loc[["Brasil","Argentina"],anos]

# %%
df_comparacao
# Out:
#            1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# País                                                                   ...
# Brasil      211   220   192   139   145   130   205   244   394   650  ...
# Argentina   368   426   626   241   237   196   213   519   374   538  ...
#
#            2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# País
# Brasil      917   969  1181  1746  2138  2509  2598  1508  1642  1714
# Argentina  1591  1153   847   620   540   467   459   278   263   282
#
# [2 rows x 34 columns]

# %%
df_comparacao = df_comparacao.T

# %%
df_comparacao
# Out:
# País  Brasil  Argentina
# 1980     211        368
# 1981     220        426
# 1982     192        626
# 1983     139        241
# 1984     145        237
# 1985     130        196
# 1986     205        213
# 1987     244        519
# 1988     394        374
# 1989     650        538
# 1990     650        678
# 1991     877        763
# 1992    1066       1023
# 1993     866       1022
# 1994     566        366
# 1995     572        380
# 1996     586        396
# 1997     591        391
# 1998     531        349
# 1999     626        318
# 2000     845        427
# 2001     847        635
# 2002     745        865
# 2003     839       1745
# 2004     917       1591
# 2005     969       1153
# 2006    1181        847
# 2007    1746        620
# 2008    2138        540
# 2009    2509        467
# 2010    2598        459
# 2011    1508        278
# 2012    1642        263
# 2013    1714        282

# %%
plt.plot(df_comparacao['Brasil'],label = 'Brasil')
plt.plot(df_comparacao['Argentina'],label ='Argentina')
plt.title('Imigração do Brasil e Argentina para o Canadá')
plt.xlabel('Ano')
plt.ylabel('Número de imigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.legend()
plt.show()

# %% [markdown]
# ### Há alguma tendência ou padrão comum nos dados dos dois países?
# ##### Os dois paises tiveram um numero de imigracao parecido entre os anos 1990 e 1995
# ### Quais são os períodos com maior número de imigrantes nos dois países?
# #####    Brasil: 2010
# #####    Argentina 2003
